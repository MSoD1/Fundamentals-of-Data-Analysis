# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# <div style="text-align: justify"> ### Exercise 1:
# *If we only wanted exactly four heads as opssosed to five, the equivalent calculation would be (10 * 9 * 8 * 7)/(4 * 3 * 2 * 1) </br>
# Does that evenly divide too? What is the formula in general? </br>
# Does it always come out as a positive whole number?*</div>

# %% [markdown]
# (10 * 9 * 8 * 7)/(4 * 3 * 2 * 1)

# %% [markdown]
# We refer to this as “N choose r.” Sometimes the number of combinations is known as a
# binomial coefficient, and sometimes the notation NCr is used. So, in the present example,
# $$
# \frac{N}{r}  = \frac{10}{4}  = \frac{N!}{r!(N-r)!}  = \frac{10!}{4!(10-4)!} = \frac{10 * 9 * 8 * 7}{4 * 3 * 2 * 1} = \frac{5040}{24} = 210
# $$ </div>

# %% [markdown]
# <div style="text-align: justify"> Yes the result based on Pascal's Rule is always a positive integer

# %% [markdown]
# ### Exercise 2:
# *Note that there are the same number of ways to get 4 tails as there to get 4 heads. Explain why this is.*

# %% [markdown]
# <div style="text-align: justify">For example, many experiments share the common element that their outcomes can be classified
# into one of two events, e.g. a coin can come up heads or tails. 4 tails becomes the 'success' and heads becomes the 'failure' resulting in the same results.</div>

# %% [markdown]
# ### Exercise 3:
# *Plot bar charts or histograms of any three different distributions listed at the following link:*

# %% [markdown]
# <div style="text-align: justify">The following returns 1000 random integers from binomial distribution with 30 trials and with success probability of each trial being 50%. From the histogram below, you can clearly see the probability of prices going up for various number of days in a month. </br>
# Next I looked at Poisson distribution. The difference is very subtle between binomial and poisson, binomial distribution is for discrete trials, whereas poisson distribution is for continuous trials.</br>
# The third plot looks at Logistic distribution which is used to describe growth. Logistric dist has three paramaters *loc* -mean, *scale* - standard deviation and *size* - the shape of the returned array.</div>

# %%
# %pip install seaborn

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
np.random.binomial(30, .5, 1000)
# Out:
# array([16, 14, 16, 17, 15, 14, 19, 12, 15, 13, 21, 15, 12, 15, 18, 17, 16,
#        12, 17, 11, 13, 15, 16, 16, 17, 18, 12, 17, 16, 12, 17, 13, 16, 14,
#        14, 21, 12, 11, 14, 12, 15, 11,  9, 16,  8, 12, 17, 13, 17, 19, 15,
#        18, 14, 13, 15, 11, 14, 15, 19, 12, 15, 12, 15,  8, 15, 13, 14, 15,
#        20,  9, 17,  8, 15, 12, 17, 13, 17, 10, 19, 16, 16, 15, 18, 17, 14,
#        13, 15, 16, 15, 17, 15, 17, 14, 17, 19, 16, 15, 11, 20, 16, 12, 15,
#        16,  9, 12, 16, 16, 20, 12, 12, 14, 17, 14, 16, 17, 16, 16, 18, 18,
#        13, 12, 16, 18, 14, 17, 17, 15, 14, 14, 11, 15, 11, 16, 16, 18, 17,
#        16, 16, 20, 15, 13, 16, 15, 17, 15, 14, 11, 19, 17, 10, 15, 17, 13,
#        10, 17, 15, 11, 12, 16, 19, 14, 17, 18, 11, 16, 13, 12, 16, 21, 13,
#        19, 14, 19, 14, 12, 16, 20, 16, 17, 16, 14, 14, 15, 21, 20, 13, 18,
#        14, 16, 13, 18, 19, 15, 18, 15, 20, 14, 12, 13, 16, 15, 16, 16, 20,
# ...

# %%
sns.displot(np.random.binomial(n=30, p=0.5, size=1000), kde=False)
plt.xlabel('Number of Days') 
plt.ylabel('Probability') 
  
# displaying the title
plt.title("Binomial Distribution")
plt.show()

# %%
sns.displot(np.random.poisson(lam=10, size=1000), kde=False, label='poisson')
plt.xlabel('Number of Days') 
plt.ylabel('Probability') 
  
# displaying the title
plt.title("Poisson Distribution")
plt.show()

# %%
sns.displot(np.random.logistic(size=1000), kde=False, label='logistic')
plt.xlabel('Number of Days') 
plt.ylabel('Probability') 
  
# displaying the title
plt.title("Logistic Distribution")
plt.show()
