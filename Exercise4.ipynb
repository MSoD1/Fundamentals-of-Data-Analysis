# %% [markdown]
# ### Week 04 - Outliers

# %%
import numpy as np

# %%
import pandas as pd

# %%
# %pip install seaborn

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# ### Exercise 1:
# *Create box plots on a single set of axes for all five experiments in the morley data set.*

# %%
# Load Dataset
data = pd.read_csv("morley.csv")

# %% [markdown]
# <div style="text-align: justify">**Note:** I used a few different methods to create a boxplot. The first approach looks at transforming the csv into a txt file, removing the header row and columns are separated by a comma. The data is the separated into 5 variables, each representing an experiment. The five variables are then grouped together in a boxplot. </div></br>

# %%
array = np.loadtxt('morley.csv', skiprows = 1,delimiter=',')

# %%
exper_1 = array[:20, 2]
exper_1
# Out:
# array([ 850.,  740.,  900., 1070.,  930.,  850.,  950.,  980.,  980.,
#         880., 1000.,  980.,  930.,  650.,  760.,  810., 1000., 1000.,
#         960.,  960.])

# %%
exper_2 = array[20:40, 2]
exper_2
# Out:
# array([960., 940., 960., 940., 880., 800., 850., 880., 900., 840., 830.,
#        790., 810., 880., 880., 830., 800., 790., 760., 800.])

# %%
exper_3 = array[40:60, 2]
exper_3
# Out:
# array([880., 880., 880., 860., 720., 720., 620., 860., 970., 950., 880.,
#        910., 850., 870., 840., 840., 850., 840., 840., 840.])

# %%
# Select the data for the fourth experiment.
exper_4 = array[60:80, 2]
exper_4
# Out:
# array([890., 810., 810., 820., 800., 770., 760., 740., 750., 760., 910.,
#        920., 890., 860., 880., 720., 840., 850., 850., 780.])

# %%
# Select the data for the fifth experiment.
exper_5 = array[80:100, 2]
exper_5
# Out:
# array([890., 840., 780., 810., 760., 810., 790., 810., 820., 850., 870.,
#        870., 810., 740., 810., 940., 950., 800., 810., 870.])

# %%
# Create a box plot.
plt.boxplot(np.array([exper_1, exper_2]).T);

# %%
plt.boxplot(np.array([exper_1, exper_2,exper_3,exper_4,exper_5]).T);
plt.xticks([1, 2, 3, 4,5])
plt.xlabel("Experiment")
plt.ylabel("Speed of Light (km/s minus 299,000)")
plt.show()

# %% [markdown]
# <div style="text-align: justify">The second approach looks at the dataset as a whole, with experiments 1-5 on the x-axis and speed on the y-axis. The swarmplot function allows use to add jitters (scatterplot result) to the boxplot to understand data within the boxplot better.</div>

# %%
ax = sns.boxplot(x='Expt', y='Speed', data=data)
plt.xlabel("Experiment")
plt.ylabel("Speed of Light (km/s minus 299,000)")
# Out:
# Text(0, 0.5, 'Speed of Light (km/s minus 299,000)')

# %%
# Add jitter with the swarmplot function
ax = sns.boxplot(x='Expt', y='Speed', data=data)
ax = sns.swarmplot(x='Expt', y='Speed', data=data, color="grey")
plt.show()

# %% [markdown]
# ### Exercise 2:
# *Create box plots for all of the numercial variables in Fisher's Iris Data Set.*

# %%
# Load Dataset
iris = pd.read_csv("iris dataset.csv")

# %%
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# Usual boxplot
ax = sns.boxplot(x='variety', y='sepal.length', data=iris)
plt.show()

# %%
# Usual boxplot
ax = sns.boxplot(x='variety', y='sepal.width', data=iris)
plt.show()

# %%
# Usual boxplot
ax = sns.boxplot(x='variety', y='petal.length', data=iris)
plt.show()

# %%
# Usual boxplot
ax = sns.boxplot(x='variety', y='petal.width', data=iris)
plt.show()

# %% [markdown]
# ### Exercise 3
# *Adapt the above code and plots (from lecture notes) so that the overall plot is inversely propertional and the individual groups are directly proportional.*

# %% [markdown]
# ![image.png](attachment:573d7df8-287f-432b-84c1-e8f059673a11.png)

# %%
# Create a series of x vectors.
xs = np.array([np.linspace(i+1, i + 2.0, 20) for i in range(10)])

# %%
ys = 1/xs

# %%
# Create global list of x and y values.
x = xs.flatten()
y= ys.flatten()

# %%
# Plot.
plt.plot(x, y, '.');

# %%
# Plot the same points, but now with a different colour for each range.
for i in range(len(xs)):
    plt.plot(xs[i], ys[i], '.')

# %%
# Same plot but with best fit lines for each category.
for i in range(len(xs)):
    # Plot this category.
    plt.plot(xs[i], ys[i], '.')
    # Fit line to category.
    m, c = np.polyfit(xs[i], ys[i], 1)
    # Create steadily increasing x range for plot.
    xbestfit = np.linspace(xs[i].min(), xs[i].max(), 50)
    # Corresponding y values based on best fit line.
    ybestfit = m*xbestfit +c
    # Plot best fit line for category.
    plt.plot(xbestfit, ybestfit, color='lightgrey');
